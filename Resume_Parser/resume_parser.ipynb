# %% [markdown]
# ## **Resume Parser Example **

# %%
import sys
import os

# Add current directory to Python path
sys.path.append(os.getcwd())

# Import the library
from resume_parser import process_resume_to_json

filename = "../Resume_Parser/Test_Resumes/Sarthak_Resume.pdf"

filename = "../Resume_Parser/Test_Resumes/Sarthak_Resume.pdf"

# Get JSON string
json_string = process_resume_to_json(filename)
print(json_string)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 8
#       5 sys.path.append(os.getcwd())
#       7 # Import the library
# ----> 8 from resume_parser import process_resume_to_json
#      10 filename = "../Resume_Parser/Test_Resumes/Sarthak_Resume.pdf"
#      12 filename = "../Resume_Parser/Test_Resumes/Sarthak_Resume.pdf"
#
# ModuleNotFoundError: No module named 'resume_parser'
